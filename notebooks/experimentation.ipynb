# %%
import sys
from pathlib import Path

project_root = Path().resolve().parent
sys.path.append(str(project_root))

print("Project root:", project_root)
# Out:
# Project root: C:\Users\nourb\OneDrive\Bureau\human-firewall\human-firewall

# %%
from backend.app.model_utils import load_dataset

df = load_dataset("../data/raw/messages_dataset.csv")
print(df.head())
print(df["label"].value_counts())
# Out:
#                                                 text label     source  \
# 0                             On se voit ce weekend?  safe  synthetic
# 1            Réunion équipe demain à 9h en salle A2.  safe  synthetic
# 2  N'oubliez pas de soumettre votre notebook avan...  safe  synthetic
# 3      Le cours de machine learning commence à 8h30.  safe  synthetic
# 4  Confirmation de votre rendez-vous le 15 avril ...  safe  synthetic
#
#   language  is_tunisian_context  \
# 0       fr                    0
# 1       fr                    0
# 2       fr                    0
# 3       fr                    0
# 4       fr                    0
#
#                                           clean_text
# 0                              on se voit ce weekend
# 1       réunion équipe demain à NUM h en salle a NUM
# 2  n oubliez pas de soumettre votre notebook avan...
# 3  le cours de machine learning commence à NUM h NUM
# 4  confirmation de votre rendez vous le NUM avril...
# label
# ...

# %%
from backend.app.model_utils import load_dataset

df = load_dataset("../data/raw/messages_dataset.csv")
print(df.head())
print(df["label"].value_counts())
print(df.columns)
# Out:
#                                                 text label     source  \
# 0                             On se voit ce weekend?  safe  synthetic
# 1            Réunion équipe demain à 9h en salle A2.  safe  synthetic
# 2  N'oubliez pas de soumettre votre notebook avan...  safe  synthetic
# 3      Le cours de machine learning commence à 8h30.  safe  synthetic
# 4  Confirmation de votre rendez-vous le 15 avril ...  safe  synthetic
#
#   language  is_tunisian_context  \
# 0       fr                    0
# 1       fr                    0
# 2       fr                    0
# 3       fr                    0
# 4       fr                    0
#
#                                           clean_text
# 0                              on se voit ce weekend
# 1       réunion équipe demain à NUM h en salle a NUM
# 2  n oubliez pas de soumettre votre notebook avan...
# 3  le cours de machine learning commence à NUM h NUM
# 4  confirmation de votre rendez vous le NUM avril...
# label
# ...

# %%
import sys
from pathlib import Path

project_root = Path().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
import sys
from pathlib import Path

project_root = Path().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
from backend.app.model_utils import predict_message

# %%
import backend.app.model_utils as mu
print(mu.__file__)
print(dir(mu))
# Out:
# C:\Users\nourb\OneDrive\Bureau\human-firewall\human-firewall\backend\app\model_utils.py
# ['BASE_DIR', 'MODEL_PATH', 'Path', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'clean_text', 'joblib', 'load_dataset', 'load_model', 'os', 'pd', 'predict_message', 're']

# %%
import sys
from pathlib import Path

project_root = Path().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print("Project root =", project_root)
print("backend visible ?", (project_root / "backend").exists())
# Out:
# Project root = C:\Users\nourb\OneDrive\Bureau\human-firewall\human-firewall
# backend visible ? True

# %%
from backend.app.model_utils import predict_message

# %%
msg = "Votre compte bancaire sera suspendu. Cliquez ici immédiatement pour vérifier vos informations."
result = predict_message(msg)

print(result)
# Out:
# {'clean_text': 'votre compte bancaire sera suspendu cliquez ici immédiatement pour vérifier vos informations', 'prediction': 'phishing', 'probabilities': {'phishing': 0.718577847958928, 'safe': 0.281422152041072}}

# %%
from backend.app.model_utils import MODEL_PATH
print(MODEL_PATH)
print(MODEL_PATH.exists())
# Out:
# C:\Users\nourb\OneDrive\Bureau\human-firewall\human-firewall\backend\models\phishing_model.joblib
# True

# %%
from backend.app.model_utils import predict_message
from backend.app.explain import explain_prediction

msg = "Urgent: your account will be locked. Click here now to verify."

pred = predict_message(msg)
exp = explain_prediction(msg)

print(pred)
print(exp)
# Out:
# {'clean_text': 'urgent your account will be locked click here now to verify', 'prediction': 'phishing', 'probabilities': {'phishing': 0.6984500391004631, 'safe': 0.3015499608995369}}
# {'rules_triggered': ['urgent', 'verify'], 'explanation': 'Alerte levée car le message contient des indices suspects : urgent, verify'}
